# %% [markdown]
# <h1><center> Data Analysis: Introduction to Pandas </center></h1>

# %% [markdown]
# <h2> Part II. Filtering and Sorting Data </h2>

# %% [markdown]
# <i>Example 1. Import the necessary libraries</i>

# %%
import pandas as pd

# %% [markdown]
# <i>Example 2. Import the dataset from the local file </i>

# %%
football = pd.read_csv('./football.csv')
football.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 0                     0  ...          13                 81.3%         41
# 1                     0  ...           9                 60.1%         53
# 2                     0  ...          10                 66.7%         25
# 3                     0  ...          22                 88.1%         43
# 4                     0  ...           6                 54.6%         36
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 0             62         2             9          0        9         9
# 1             73         8             7          0       11        11
# 2             38         8             4          0        7         7
# 3             45         6             5          0       11        11
# 4             51         5             6          0       11        11
#
#    Players Used
# 0            16
# 1            19
# 2            15
# 3            16
# 4            19
#
# [5 rows x 35 columns]

# %% [markdown]
# <b>Exercise 1. Display all the attributes of the dataset.</b>

# %%
football.columns
football.info
# Out:
# <bound method DataFrame.info of                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# 13                Spain     12               42                33
# 14               Sweden      5               17                19
# 15              Ukraine      2                7                26
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 0              51.9%            16.0%                          32
# 1              41.9%            12.9%                          39
# 2              50.0%            20.0%                          27
# 3              50.0%            17.2%                          40
# 4              37.9%             6.5%                          65
# 5              47.8%            15.6%                          80
# 6              30.7%            19.2%                          32
# 7              43.0%             7.5%                         110
# 8              25.0%             4.1%                          60
# 9              39.4%             5.2%                          48
# 10             34.3%             9.3%                          82
# 11             36.8%             5.2%                          28
# 12             22.5%            12.5%                          59
# 13             55.9%            16.0%                         100
# 14             47.2%            13.8%                          39
# 15             21.2%             6.0%                          38
#
#     Hit Woodwork  Penalty goals  Penalties not scored  ...  Saves made  \
# 0              0              0                     0  ...          13
# 1              0              0                     0  ...           9
# 2              1              0                     0  ...          10
# 3              0              0                     0  ...          22
# 4              1              0                     0  ...           6
# 5              2              1                     0  ...          10
# 6              1              1                     1  ...          13
# 7              2              0                     0  ...          20
# 8              2              0                     0  ...          12
# 9              0              0                     0  ...           6
# 10             6              0                     0  ...          10
# 11             0              0                     0  ...          17
# 12             2              0                     0  ...          10
# 13             0              1                     0  ...          15
# 14             3              0                     0  ...           8
# 15             0              0                     0  ...          13
#
#     Saves-to-shots ratio  Fouls Won Fouls Conceded  Offsides  Yellow Cards  \
# 0                  81.3%         41             62         2             9
# 1                  60.1%         53             73         8             7
# 2                  66.7%         25             38         8             4
# 3                  88.1%         43             45         6             5
# 4                  54.6%         36             51         5             6
# 5                  62.6%         63             49        12             4
# 6                  65.1%         67             48        12             9
# 7                  74.1%        101             89        16            16
# 8                  70.6%         35             30         3             5
# 9                  66.7%         48             56         3             7
# 10                 71.5%         73             90        10            12
# 11                 65.4%         43             51        11             6
# 12                 77.0%         34             43         4             6
# 13                 93.8%        102             83        19            11
# 14                 61.6%         35             51         7             7
# 15                 76.5%         48             31         4             5
#
#     Red Cards  Subs on  Subs off  Players Used
# 0           0        9         9            16
# 1           0       11        11            19
# 2           0        7         7            15
# 3           0       11        11            16
# 4           0       11        11            19
# 5           0       15        15            17
# 6           1       12        12            20
# 7           0       18        18            19
# 8           0        7         7            15
# 9           1        7         7            17
# 10          0       14        14            16
# 11          1       10        10            17
# 12          0        7         7            16
# 13          0       17        17            18
# 14          0        9         9            18
# 15          0        9         9            18
#
# [16 rows x 35 columns]>

# %% [markdown]
# <b>Exercise 2. Display the <i>"Team"</i> and <i>"Goals"</i>column.</b>

# %%
football[["Team", "Goals"]]
# Out:
#                    Team  Goals
# 0               Croatia      4
# 1        Czech Republic      4
# 2               Denmark      4
# 3               England      5
# 4                France      3
# 5               Germany     10
# 6                Greece      5
# 7                 Italy      6
# 8           Netherlands      2
# 9                Poland      2
# 10             Portugal      6
# 11  Republic of Ireland      1
# 12               Russia      5
# 13                Spain     12
# 14               Sweden      5
# 15              Ukraine      2

# %% [markdown]
# <b>Exercise 3. Display all the countries which joined the competition. How many countries competed in the competition?</b>

# %%
total_countries = football["Team"].nunique()
print(f"There are {total_countries} countries join the competition")
# Out:
# There are 16 countries join the competition

# %% [markdown]
# <b>Exercise 4. Select the <i>"Shots on target"</i>, <i>"Shots off target"and</i> <i>"Shooting Accuracy"</i> columns and assign these columns to the new dataframe "Shooting Information". Sort the list by the number of shots on target. </b>

# %%
Shooting_Information = football[['Shots on target', 'Shots off target', 'Shooting Accuracy']].sort_values(by='Shots off target', ascending=False)
Shooting_Information
# Out:
#     Shots on target  Shots off target Shooting Accuracy
# 7                34                45             43.0%
# 10               22                42             34.3%
# 8                12                36             25.0%
# 13               42                33             55.9%
# 5                32                32             47.8%
# 12                9                31             22.5%
# 15                7                26             21.2%
# 4                22                24             37.9%
# 9                15                23             39.4%
# 14               17                19             47.2%
# 1                13                18             41.9%
# 3                11                18             50.0%
# 6                 8                18             30.7%
# 0                13                12             51.9%
# 11                7                12             36.8%
# 2                10                10             50.0%

# %% [markdown]
# <b>Exercise 5. Display the first 5 columns and assign them into a new dataframe called "First_Five".</b>

# %%
First_Five = football[football.columns[0:5]]
First_Five
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# 13                Spain     12               42                33
# 14               Sweden      5               17                19
# 15              Ukraine      2                7                26
#
#    Shooting Accuracy
# 0              51.9%
# 1              41.9%
# 2              50.0%
# 3              50.0%
# 4              37.9%
# 5              47.8%
# 6              30.7%
# 7              43.0%
# 8              25.0%
# 9              39.4%
# 10             34.3%
# 11             36.8%
# 12             22.5%
# 13             55.9%
# 14             47.2%
# 15             21.2%

# %% [markdown]
# <b>Exercise 6. Display all columns except the last 4 columns.</b>

# %%
except_last_four = football[football.columns[0:-4]]
except_last_four
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# 13                Spain     12               42                33
# 14               Sweden      5               17                19
# 15              Ukraine      2                7                26
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 0              51.9%            16.0%                          32
# 1              41.9%            12.9%                          39
# 2              50.0%            20.0%                          27
# 3              50.0%            17.2%                          40
# 4              37.9%             6.5%                          65
# 5              47.8%            15.6%                          80
# 6              30.7%            19.2%                          32
# 7              43.0%             7.5%                         110
# 8              25.0%             4.1%                          60
# 9              39.4%             5.2%                          48
# 10             34.3%             9.3%                          82
# 11             36.8%             5.2%                          28
# 12             22.5%            12.5%                          59
# 13             55.9%            16.0%                         100
# 14             47.2%            13.8%                          39
# 15             21.2%             6.0%                          38
#
#     Hit Woodwork  Penalty goals  Penalties not scored  ...  \
# 0              0              0                     0  ...
# 1              0              0                     0  ...
# 2              1              0                     0  ...
# 3              0              0                     0  ...
# 4              1              0                     0  ...
# 5              2              1                     0  ...
# 6              1              1                     1  ...
# 7              2              0                     0  ...
# 8              2              0                     0  ...
# 9              0              0                     0  ...
# 10             6              0                     0  ...
# 11             0              0                     0  ...
# 12             2              0                     0  ...
# 13             0              1                     0  ...
# 14             3              0                     0  ...
# 15             0              0                     0  ...
#
#     Clearances off line  Clean Sheets  Blocks Goals conceded  Saves made  \
# 0                   NaN             0      10              3          13
# 1                   2.0             1      10              6           9
# 2                   0.0             1      10              5          10
# 3                   1.0             2      29              3          22
# 4                   0.0             1       7              5           6
# 5                   0.0             1      11              6          10
# 6                   0.0             1      23              7          13
# 7                   1.0             2      18              7          20
# 8                   0.0             0       9              5          12
# 9                   0.0             0       8              3           6
# 10                  0.0             2      11              4          10
# 11                  1.0             0      23              9          17
# 12                  0.0             0       8              3          10
# 13                  0.0             5       8              1          15
# 14                  0.0             1      12              5           8
# 15                  0.0             0       4              4          13
#
#     Saves-to-shots ratio  Fouls Won  Fouls Conceded  Offsides  Yellow Cards
# 0                  81.3%         41              62         2             9
# 1                  60.1%         53              73         8             7
# 2                  66.7%         25              38         8             4
# 3                  88.1%         43              45         6             5
# 4                  54.6%         36              51         5             6
# 5                  62.6%         63              49        12             4
# 6                  65.1%         67              48        12             9
# 7                  74.1%        101              89        16            16
# 8                  70.6%         35              30         3             5
# 9                  66.7%         48              56         3             7
# 10                 71.5%         73              90        10            12
# 11                 65.4%         43              51        11             6
# 12                 77.0%         34              43         4             6
# 13                 93.8%        102              83        19            11
# 14                 61.6%         35              51         7             7
# 15                 76.5%         48              31         4             5
#
# [16 rows x 31 columns]

# %% [markdown]
# <b>Exercise 7. Sort the list of countries by the number of fouls won and then the number of fouls conceded.</b>

# %%
list_of_countries = football[['Team', 'Fouls Won', 'Fouls Conceded']
].sort_values(by=['Fouls Won', 'Fouls Conceded'], ascending=False)
list_of_countries
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 13                Spain     12               42                33
# 7                 Italy      6               34                45
# 10             Portugal      6               22                42
# 6                Greece      5                8                18
# 5               Germany     10               32                32
# 1        Czech Republic      4               13                18
# 9                Poland      2               15                23
# 15              Ukraine      2                7                26
# 11  Republic of Ireland      1                7                12
# 3               England      5               11                18
# 0               Croatia      4               13                12
# 4                France      3               22                24
# 14               Sweden      5               17                19
# 8           Netherlands      2               12                36
# 12               Russia      5                9                31
# 2               Denmark      4               10                10
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 13             55.9%            16.0%                         100
# 7              43.0%             7.5%                         110
# 10             34.3%             9.3%                          82
# 6              30.7%            19.2%                          32
# 5              47.8%            15.6%                          80
# 1              41.9%            12.9%                          39
# 9              39.4%             5.2%                          48
# 15             21.2%             6.0%                          38
# 11             36.8%             5.2%                          28
# 3              50.0%            17.2%                          40
# 0              51.9%            16.0%                          32
# 4              37.9%             6.5%                          65
# 14             47.2%            13.8%                          39
# 8              25.0%             4.1%                          60
# 12             22.5%            12.5%                          59
# 2              50.0%            20.0%                          27
#
#     Hit Woodwork  Penalty goals  Penalties not scored  ...  Saves made  \
# 13             0              1                     0  ...          15
# 7              2              0                     0  ...          20
# 10             6              0                     0  ...          10
# 6              1              1                     1  ...          13
# 5              2              1                     0  ...          10
# 1              0              0                     0  ...           9
# 9              0              0                     0  ...           6
# 15             0              0                     0  ...          13
# 11             0              0                     0  ...          17
# 3              0              0                     0  ...          22
# 0              0              0                     0  ...          13
# 4              1              0                     0  ...           6
# 14             3              0                     0  ...           8
# 8              2              0                     0  ...          12
# 12             2              0                     0  ...          10
# 2              1              0                     0  ...          10
#
#     Saves-to-shots ratio  Fouls Won Fouls Conceded  Offsides  Yellow Cards  \
# 13                 93.8%        102             83        19            11
# 7                  74.1%        101             89        16            16
# 10                 71.5%         73             90        10            12
# 6                  65.1%         67             48        12             9
# 5                  62.6%         63             49        12             4
# 1                  60.1%         53             73         8             7
# 9                  66.7%         48             56         3             7
# 15                 76.5%         48             31         4             5
# 11                 65.4%         43             51        11             6
# 3                  88.1%         43             45         6             5
# 0                  81.3%         41             62         2             9
# 4                  54.6%         36             51         5             6
# 14                 61.6%         35             51         7             7
# 8                  70.6%         35             30         3             5
# 12                 77.0%         34             43         4             6
# 2                  66.7%         25             38         8             4
#
#     Red Cards  Subs on  Subs off  Players Used
# 13          0       17        17            18
# 7           0       18        18            19
# 10          0       14        14            16
# 6           1       12        12            20
# 5           0       15        15            17
# 1           0       11        11            19
# 9           1        7         7            17
# 15          0        9         9            18
# 11          1       10        10            17
# 3           0       11        11            16
# 0           0        9         9            16
# 4           0       11        11            19
# 14          0        9         9            18
# 8           0        7         7            15
# 12          0        7         7            16
# 2           0        7         7            15
#
# [16 rows x 35 columns]

# %% [markdown]
# <b>Exercise 8. Find the mean of Players Used in a team.

# %%
mean = football['Players Used'].mean()
print(f"The average number of players used by each country is {mean}")
# Out:
# The average number of players used by each country is 17.25

# %% [markdown]
# <b>Exercise 9. Display the list of team(s) which score(s) more than 10 goals.

# %%
football[football['Goals'] > 10][['Team', 'Goals']]
#Or
football.loc[football['Goals'] > 10, ['Team', 'Goals']]
# Out:
#      Team  Goals
# 13  Spain     12

# %% [markdown]
# <b>Exercise 10. Display the countries which begins with letter "P"</b>

# %%
football[football['Team'].str.startswith("P")]
# Out:
#         Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 9     Poland      2               15                23             39.4%
# 10  Portugal      6               22                42             34.3%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 9              5.2%                          48             0              0
# 10             9.3%                          82             6              0
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 9                      0  ...           6                 66.7%         48
# 10                     0  ...          10                 71.5%         73
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 9              56         3             7          1        7         7
# 10             90        10            12          0       14        14
#
#     Players Used
# 9             17
# 10            16
#
# [2 rows x 35 columns]

# %% [markdown]
# <b>Exercise 11. Display the <i>"Shots on target"</i>, <i>"Shots off target"and</i> <i>"Shooting Accuracy"</i> from Portugal, Germany, Sweden and England.</b>

# %%
football[football['Team'].isin(['Portugal', 'Germany', 'Sweden', 'England'])][['Team', 'Shots on target', 'Shots off target', 'Shooting Accuracy']]
# Out:
#         Team  Shots on target  Shots off target Shooting Accuracy
# 3    England               11                18             50.0%
# 5    Germany               32                32             47.8%
# 10  Portugal               22                42             34.3%
# 14    Sweden               17                19             47.2%
